# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import numpy as np

# %% [markdown]
# ### Reading the dataset

# %%
flights_url = "https://github.com/byuidatascience/data4python4ds/raw/master/data-raw/flights/flights.csv"

# %%
df = pd.read_csv("https://github.com/byuidatascience/data4python4ds/raw/master/data-raw/flights/flights.csv")

# %%
df.head(10)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
# 5  2013      1    1     554.0             558       -4.0     740.0
# 6  2013      1    1     555.0             600       -5.0     913.0
# 7  2013      1    1     557.0             600       -3.0     709.0
# 8  2013      1    1     557.0             600       -3.0     838.0
# 9  2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# ...

# %%
dic = {'Name': ['Omolewa', 'Bukola'],
      'lname': ['Adaramola', 'David'],
      'mname': ['', 'Joseph']}

# %%
dic.keys()
# Out:
# dict_keys(['Name', 'lname', 'mname'])

# %%
dic.values()
# Out:
# dict_values([['Omolewa', 'Bukola'], ['Adaramola', 'David'], ['', 'Joseph']])

# %%
dic['Name']
# Out:
# ['Omolewa', 'Bukola']

# %%
df['year']
# Out:
# 0         2013
# 1         2013
# 2         2013
# 3         2013
# 4         2013
#           ...
# 336771    2013
# 336772    2013
# 336773    2013
# 336774    2013
# 336775    2013
# Name: year, Length: 336776, dtype: int64

# %%
df.shape
# Out:
# (336776, 19)

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['year',
#  'month',
#  'day',
#  'dep_time',
#  'sched_dep_time',
#  'dep_delay',
#  'arr_time',
#  'sched_arr_time',
#  'arr_delay',
#  'carrier',
#  'flight',
#  'tailnum',
#  'origin',
#  'dest',
#  'air_time',
#  'distance',
#  'hour',
#  'minute',
#  'time_hour']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
# ...

# %%
df.isna()
# Out:
#          year  month    day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       False  False  False     False           False      False     False
# 1       False  False  False     False           False      False     False
# 2       False  False  False     False           False      False     False
# 3       False  False  False     False           False      False     False
# 4       False  False  False     False           False      False     False
# ...       ...    ...    ...       ...             ...        ...       ...
# 336771  False  False  False      True           False       True      True
# 336772  False  False  False      True           False       True      True
# 336773  False  False  False      True           False       True      True
# 336774  False  False  False      True           False       True      True
# 336775  False  False  False      True           False       True      True
#
# ...

# %%
sum(df.isna()['dep_time'])
# Out:
# 8255

# %%
for col in list(df.columns):
    print(f'{col}: {sum(df.isna()[col])}')
# Out:
# year: 0
# month: 0
# day: 0
# dep_time: 8255
# sched_dep_time: 0
# dep_delay: 8255
# arr_time: 8713
# sched_arr_time: 0
# arr_delay: 9430
# carrier: 0
# flight: 0
# tailnum: 2512
# origin: 0
# dest: 0
# air_time: 9430
# distance: 0
# hour: 0
# minute: 0
# time_hour: 0

# %%
df.isna().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %%
df.fillna()

# %%
df.dtypes
# Out:
# year                int64
# month               int64
# day                 int64
# dep_time          float64
# sched_dep_time      int64
# dep_delay         float64
# arr_time          float64
# sched_arr_time      int64
# arr_delay         float64
# carrier            object
# flight              int64
# tailnum            object
# origin             object
# dest               object
# air_time          float64
# distance            int64
# hour                int64
# minute              int64
# time_hour          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
# ...

# %%
df_1 = df.query('month == 1 & day == 1')

# %%
df_1.to_csv('Manager_request.csv')

# %%
df.query('month == 11 | month == 12')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 55893   2013     11    1       5.0            2359        6.0     352.0
# 55894   2013     11    1      35.0            2250      105.0     123.0
# 55895   2013     11    1     455.0             500       -5.0     641.0
# 55896   2013     11    1     539.0             545       -6.0     856.0
# 55897   2013     11    1     542.0             545       -3.0     831.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 111291  2013     12   31       NaN             705        NaN       NaN
# 111292  2013     12   31       NaN             825        NaN       NaN
# 111293  2013     12   31       NaN            1615        NaN       NaN
# 111294  2013     12   31       NaN             600        NaN       NaN
# 111295  2013     12   31       NaN             830        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
# loc, iloc

# %%
df.loc[(df['month'] == 11) & (df['dep_time'] == 5.0)]
# Out:
#        year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 55893  2013     11    1       5.0            2359        6.0     352.0
# 78064  2013     11   25       5.0            2359        6.0     436.0
#
#        sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 55893             345        7.0      B6     745  N568JB    JFK  PSE
# 78064             445       -9.0      B6     745  N597JB    JFK  PSE
#
#        air_time  distance  hour  minute             time_hour
# 55893     205.0      1617    23      59  2013-11-02T03:00:00Z
# 78064     193.0      1617    23      59  2013-11-26T04:00:00Z

# %%
df.loc[:10]
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   2013      1    1     517.0             515        2.0     830.0
# 1   2013      1    1     533.0             529        4.0     850.0
# 2   2013      1    1     542.0             540        2.0     923.0
# 3   2013      1    1     544.0             545       -1.0    1004.0
# 4   2013      1    1     554.0             600       -6.0     812.0
# 5   2013      1    1     554.0             558       -4.0     740.0
# 6   2013      1    1     555.0             600       -5.0     913.0
# 7   2013      1    1     557.0             600       -3.0     709.0
# 8   2013      1    1     557.0             600       -3.0     838.0
# 9   2013      1    1     558.0             600       -2.0     753.0
# 10  2013      1    1     558.0             600       -2.0     849.0
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
time = 515

# %%
515/100
# Out:
# 5.15

# %%
time//100
# Out:
# 5

# %%
time % 100
# Out:
# 15

# %%
int(str(time)[1:])
# Out:
# 15

# %%
def convert_time_hr(time):
    return time//100

def convert_time_min(time):
    return time % 100

# %%
def convert_time(time):
    hr = time//100
    mn = time % 100
    return f'{hr}:{mn}'

# %%
convert_time(515)
# Out:
# '5:15'

# %%
df['sched_dep_time_HR'] = df['sched_dep_time'].apply(convert_time_hr)
df['sched_dep_time_MIN'] = df['sched_dep_time'].apply(convert_time_min)

# %%
df['sched_dep_time'] = df['sched_dep_time'].apply(convert_time)

# %%
df.head()
# Out:
#    year  month  day  dep_time sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0           5:15        2.0     830.0
# 1  2013      1    1     533.0           5:29        4.0     850.0
# 2  2013      1    1     542.0           5:40        2.0     923.0
# 3  2013      1    1     544.0           5:45       -1.0    1004.0
# 4  2013      1    1     554.0            6:0       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0             819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1             830       20.0      UA  ...   N24211    LGA  IAH    227.0
# 2             850       33.0      AA  ...   N619AA    JFK  MIA    160.0
# 3            1022      -18.0      B6  ...   N804JB    JFK  BQN    183.0
# 4             837      -25.0      DL  ...   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute             time_hour sched_dep_time_HR  \
# ...

# %%
df[['year', 'sched_dep_time']]
# Out:
#         year sched_dep_time
# 0       2013           5:15
# 1       2013           5:29
# 2       2013           5:40
# 3       2013           5:45
# 4       2013            6:0
# ...      ...            ...
# 336771  2013          14:55
# 336772  2013           22:0
# 336773  2013          12:10
# 336774  2013          11:59
# 336775  2013           8:40
#
# [336776 rows x 2 columns]

# %%
df['origin'].nunique()
# Out:
# 3

# %%
df['origin'].unique()
# Out:
# array(['EWR', 'LGA', 'JFK'], dtype=object)

# %%
df['sched_dep_time_HR'].value_counts()
# Out:
# 8     27242
# 6     25951
# 17    24426
# 15    23888
# 16    23002
# 7     22821
# 18    21783
# 14    21706
# 19    21441
# 9     20312
# 13    19956
# 12    18181
# 20    16739
# 10    16708
# 11    16033
# 21    10933
# 22     2639
# 5      1953
# 23     1061
# 1         1
# Name: sched_dep_time_HR, dtype: int64

# %%
df.dtypes
# Out:
# year                    int64
# month                   int64
# day                     int64
# dep_time              float64
# sched_dep_time         object
# dep_delay             float64
# arr_time              float64
# sched_arr_time          int64
# arr_delay             float64
# carrier                object
# flight                  int64
# tailnum                object
# origin                 object
# dest                   object
# air_time              float64
# distance                int64
# hour                    int64
# minute                  int64
# time_hour              object
# sched_dep_time_HR       int64
# sched_dep_time_MIN      int64
# dtype: object

# %%
df['time_hour'] = pd.to_datetime(df['time_hour'])

# %%
df.dtypes
# Out:
# year                                int64
# month                               int64
# day                                 int64
# dep_time                          float64
# sched_dep_time                     object
# dep_delay                         float64
# arr_time                          float64
# sched_arr_time                      int64
# arr_delay                         float64
# carrier                            object
# flight                              int64
# tailnum                            object
# origin                             object
# dest                               object
# air_time                          float64
# distance                            int64
# hour                                int64
# minute                              int64
# time_hour             datetime64[ns, UTC]
# sched_dep_time_HR                   int64
# sched_dep_time_MIN                  int64
# dtype: object

# %% [markdown]
# Find all flights that
#
# A. Had an arrival delay of two or more hours
#
# B. Flew to Houston (IAH or HOU)
#
# C. Were operated by United, American, or Delta
#
# D. Departed in summer (July, August, and September)
#
# E. Arrived more than two hours late, but didn’t leave late
#
# F. Were delayed by at least an hour, but made up over 30 minutes in flight
#
# G. Departed between midnight and 6am (inclusive)
#
# How many flights have a missing dep_time? What other variables are missing? What might these rows represent?

# %%
df.loc[df['arr_delay'] > 2].shape[0]
# Out:
# 123096

# %%
df.loc[(df['dest'] == 'IAH') | (df['dest'] == 'HOU')]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 32      2013      1    1     623.0             627       -4.0     933.0
# 81      2013      1    1     728.0             732       -4.0    1041.0
# 89      2013      1    1     739.0             739        0.0    1104.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336524  2013      9   30    1729.0            1720        9.0    2001.0
# 336527  2013      9   30    1735.0            1715       20.0    2010.0
# 336618  2013      9   30    1859.0            1859        0.0    2134.0
# 336694  2013      9   30    2015.0            2015        0.0    2244.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
True + True
# Out:
# 2

# %%
False + True
# Out:
# 1

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# ...

# %%
flights['dep_time']
# Out:
# 0         517.0
# 1         533.0
# 2         542.0
# 3         544.0
# 4         554.0
#           ...
# 336771      NaN
# 336772      NaN
# 336773      NaN
# 336774      NaN
# 336775      NaN
# Name: dep_time, Length: 336776, dtype: float64
